# %% [markdown]
# # UMP01: Anschaffung von Laptops und Tablets
#
# ## Lösung LP in Matrix Notation
# Nachfolgendes Skript zeigt die Lösung des Modells als LP, d.h. als lineares Programm, ausgehend von einer Formulierung in **Matrix-Notation**.
#
# Eigentlich handelt es sich hier um ein ILP (d.h. ein ganzzahliges lineares Programm), aber das Modell wird hier als LP formuliert. Lineare Programme sind für die Solver viel einfacher zu lösen als ganzzahlig lineare Programme. Grundsätzlich müssen Probleme als ILP formuliert werden, sobald mindestens eine Entscheidungsvariable Ganzzahligkeit fordert. In der Vorlesung lernen Sie aber, wann ein Problem auch praktikabel als LP (ohne I für Integer, d.h. ohne Ganzzahligkeit) formuliert werden darf und wie dann die Lösungen zu interpretieren sind.
#
# **Hinweis:** Um den Sourcecode hinter der Funktion (solve_ump01_as_lp) anzuzeigen, drücken Sie Sie in VSCode einfach die Ctrl-Taste und clicken Sie mit dem Mousepointer auf den Funktionsnamen. Danach kehren Sie mit Alt+'<-' (Rückwärtspfeil-Taste) wieder zum zuletzt angezeigten Fenster (d.h. dieses Jupyter Notebook) zurück.

# %%
from UMP01_LP_MATRIX_NOTATION import *

main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from UMP01_LP_MATRIX_NOTATION import *
#       3 main()
#
# File c:\Users\marck\Documents\_OST\OPRE\LB1_LP_SAMPLE\UMP01_LP_MATRIX_NOTATION.py:1
# ----> 1 from scipy.optimize import linprog
#       3 def main():
#       4      c = [-1, -1]
#
# File c:\Users\marck\Documents\_OST\OPRE\.venv\Lib\site-packages\scipy\optimize\__init__.py:422
#       1 """
#       2 =====================================================
#       3 Optimization and root finding (:mod:`scipy.optimize`)
#    (...)    419
#     420 """  # noqa: E501
# --> 422 from ._optimize import *
#     423 from ._minimize import *
#     424 from ._root import *
#
# File c:\Users\marck\Documents\_OST\OPRE\.venv\Lib\site-packages\scipy\optimize\_optimize.py:34
#      32 from numpy import eye, argmin, zeros, shape, asarray, sqrt
#      33 import numpy as np
# ---> 34 from scipy.linalg import cholesky, issymmetric, LinAlgError
#      35 from scipy.sparse.linalg import LinearOperator
#      36 from ._linesearch import (line_search_wolfe1, line_search_wolfe2,
#      37                           line_search_wolfe2 as line_search,
#      38                           LineSearchWarning)
#
# File c:\Users\marck\Documents\_OST\OPRE\.venv\Lib\site-packages\scipy\linalg\__init__.py:204
#       1 """
#       2 ====================================
#       3 Linear algebra (:mod:`scipy.linalg`)
#    (...)    200
#     201 """  # noqa: E501
#     203 from ._misc import *
# --> 204 from ._cythonized_array_utils import *
#     205 from ._basic import *
#     206 from ._decomp import *
#
# File scipy/linalg/_cythonized_array_utils.pyx:11, in init scipy.linalg._cythonized_array_utils()
#
# File c:\Users\marck\Documents\_OST\OPRE\.venv\Lib\site-packages\scipy\_lib\_util.py:14
#      11 from typing import Literal, TypeAlias, TypeVar
#      13 import numpy as np
# ---> 14 from scipy._lib._array_api import (Array, array_namespace, is_lazy_array,
#      15                                    is_numpy, is_marray, xp_result_device,
#      16                                    xp_size, xp_result_type)
#      17 from scipy._lib._docscrape import FunctionDoc, Parameter
#      18 from scipy._lib._sparse import issparse
#
# File c:\Users\marck\Documents\_OST\OPRE\.venv\Lib\site-packages\scipy\_lib\_array_api.py:25
#      22 import numpy.typing as npt
#      24 from scipy._lib import array_api_compat
# ---> 25 from scipy._lib.array_api_compat import (
#      26     is_array_api_obj,
#      27     is_lazy_array,
#      28     size as xp_size,
#      29     numpy as np_compat,
#      30     device as xp_device,
#      31     is_numpy_namespace as is_numpy,
#      32     is_cupy_namespace as is_cupy,
#      33     is_torch_namespace as is_torch,
#      34     is_jax_namespace as is_jax,
#      35     is_dask_namespace as is_dask,
#      36     is_array_api_strict_namespace as is_array_api_strict
#      37 )
#      38 from scipy._lib._sparse import issparse
#      39 from scipy._lib._docscrape import FunctionDoc
#
# File c:\Users\marck\Documents\_OST\OPRE\.venv\Lib\site-packages\scipy\_lib\array_api_compat\numpy\__init__.py:4
#       1 # ruff: noqa: PLC0414
#       2 from typing import Final
# ----> 4 from numpy import *  # noqa: F403  # pyright: ignore[reportWildcardImportFromLibrary]
#       6 # from numpy import * doesn't overwrite these builtin names
#       7 from numpy import abs as abs
#
# File <frozen importlib._bootstrap>:1410, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\marck\Documents\_OST\OPRE\.venv\Lib\site-packages\numpy\__init__.py:734, in __getattr__(attr)
#     732     return dtypes
#     733 elif attr == "random":
# --> 734     import numpy.random as random
#     735     return random
#     736 elif attr == "polynomial":
#
# File c:\Users\marck\Documents\_OST\OPRE\.venv\Lib\site-packages\numpy\random\__init__.py:180
#     126 __all__ = [
#     127     'beta',
#     128     'binomial',
#    (...)    176     'zipf',
#     177 ]
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _bounded_integers, _common, _pickle
#     181 from ._generator import Generator, default_rng
#     182 from ._mt19937 import MT19937
#
# File c:\Users\marck\Documents\_OST\OPRE\.venv\Lib\site-packages\numpy\random\_pickle.py:4
#       2 from ._mt19937 import MT19937
#       3 from ._pcg64 import PCG64, PCG64DXSM
# ----> 4 from ._philox import Philox
#       5 from ._sfc64 import SFC64
#       6 from .bit_generator import BitGenerator
#
# File <frozen importlib._bootstrap>:645, in parent(self)
#
# KeyboardInterrupt:

# %% [markdown]
# Der Zielfunktionswert muss hier mit (-1) multipliziert werden, da wir die Zielfunktion wegen des eingesetzten Solvers auf 'minimiere...' umstellen mussten, wir aber (Anzahl Geräte) maximieren wollen. Damit liegt die optimale Anzahl bei 400 Geräten.
#
# Lösung: Das Softwareunternehmen sollte 100 Laptops und 300 Tablets kaufen (im Gesamtwert von 100*800+300*400 CHF = 200'000 CHF).

# %% [markdown]
# ## Lösung ILP in Matrix Notation
# Nachfolgendes Skript demonstriert, wie die Aufgabe als ILP formuliert werden kann, d.h. als ganzzahlig lineares Programm. Ebenfalls wird hier das Modell auf Basis einer Formulierung in **Matrix-Notation** gelöst.

# %%
from UMP01_ILP_MATRIX_NOTATION import *

main()
# Out:
# Optimization terminated successfully. (HiGHS Status 7: Optimal)
# Objective value:	-400.0
# Results:			[100. 300.]

# %% [markdown]
# Die Lösung bleibt unverändert. Glücklicherweise lieferte die LP-Lösung ebenfalls eine ganzzahlige Lösung, so dass die Lösung (Anzahl Geräte) nicht interpretiert (auf geeignete Weise gerundet) werden musste.
#
# Lösung: Das Softwareunternehmen sollte 100 Laptops und 300 Tablets kaufen (im Gesamtwert von 100*800+300*400 CHF = 200'000 CHF).
