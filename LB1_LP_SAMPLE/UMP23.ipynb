# %% [markdown]
# # UMP23: Kursplanung
#
# ## Lösung ILP in algebraischer Notation
# Nachfolgendes Skript zeigt die Lösung des Modells als ILP, d.h. als ganzzahlig lineares Programm, ausgehend von einer Formulierung in **algebraischer Notation**.

# %%
from UMP23_ILP_ALGEBRAIC_NOTATION import *

main()
# Out:
# Solution:
# Objective value = 36000.0
# X_0 = 0.0
# X_1 = 0.0
# X_2 = 1.0
# X_3 = 0.0
# X_4 = 1.0
# X_5 = 1.0
# X_6 = 0.0
# X_7 = 0.0
# X_8 = 1.0
# X_9 = 1.0

# %% [markdown]
# Lösung: Der Schriftsteller soll die Kurse 3, 5, 6, 9 und 10 anbieten. Er erzielt damit einen Gesamtertrag von 36'000 CHF.
