# %% [markdown]
# # UMP18: Positionierung von Feuerwehrfahrzeugen
#
# ## Lösung ILP in Matrix Notation
# Nachfolgendes Skript zeigt die Lösung des Modells als ILP, d.h. als ganzzahlig lineares Programm, ausgehend von einer Formulierung in **Matrix Notation**.

# %%
from UMP18_ILP_MATRIX_NOTATION import *

main()
# Out:
# Optimization terminated successfully. (HiGHS Status 7: Optimal)
# Objective value:	2.0
# Results:			[0. 1. 0. 1. 0. 0.]

# %% [markdown]
# Lösung: Die Gemeinden brauchen 2 Feuerwehrautos. Je eins soll in Dorf 2 und eines in Dorf 4 stationiert sein.

# %% [markdown]
# ## Lösung ILP in algebraischer Notation
# Nachfolgendes Skript zeigt die Lösung des Modells als ILP, d.h. als ganzzahlig lineares Programm, ausgehend von einer Formulierung in **algebraischer Notation**.

# %%
from UMP18_ILP_ALGEBRAIC_NOTATION import *

main()
# Out:
# Solution:
# Objective value = 2.0
# X_0 = 0
# X_1 = 1
# X_2 = 0
# X_3 = 1
# X_4 = 0
# X_5 = 0

# %% [markdown]
# Die Lösung bleibt sich natürlich gleich, egal welche der beiden Formulierungen (Matrix- oder algebraische Notation) wir wählen.
#
# Lösung: Die Gemeinden brauchen 2 Feuerwehrautos. Je eins soll in Dorf 2 und eines in Dorf 4 stationiert sein.
